# %%
# !pip install -q langchain_community langchain openai
# !pip install -q huggingface_hub transformers sentencepiece accelerate bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 31.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 29.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 59.1 MB/s eta 0:00:00

# %%
from google.colab import userdata
openai_api_key = userdata.get('openai_api_key')

# %%
from langchain.llms import OpenAI

# %%
llm = OpenAI(openai_api_key = openai_api_key, model_name = "text-davinci-003")
# Out:
# <ipython-input-4-36494115d580>:1: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm = OpenAI(openai_api_key = openai_api_key, model_name = "text-davinci-003")

# %% [markdown]
# ## Templates

# %%
from langchain.prompts import PromptTemplate

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_id = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)

chat = pipeline("text-generation", model=model, tokenizer=tokenizer)

def ask(question):
    prompt = f"<|user|>\n{question}\n<|assistant|>\n"
    response = chat(prompt, max_new_tokens=100, do_sample=True, temperature=0.7)
    print(response[0]["generated_text"])
# Out:
# Device set to use cpu
# The capital of France is Paris.

# %%
prompt = PromptTemplate.from_template("give me roadmap to learn this {subject}")
subject = "Machine Learning"
prompt = prompt.format(subject = subject)
ask(prompt)

# print( llm (prompt )) # if you have paid api_key from openai --> run this line
# Out:
# I can provide you with a general roadmap to learn machine learning:
#
# 1. Understand the basics:
#    a. Understand the concepts of data, algorithms, and machine learning.
#    b. Familiarize yourself with different types of machine learning algorithms like regression, classification, clustering, and reinforcement learning.
#    c. Learn fundamentals like calculus, statistics, and programming.
#
# 2. Start with simple tasks:
#    a.

# %%
prompt = PromptTemplate(
    template="give me roadmap to learn this {subject} and give me anwers using {language} ",
    input_vaiables = ["subject", "language"]
)
subject = "Machine Learning"
language = "English"

prompt = prompt.format(subject = subject, language = language)

ask(prompt)
# print( llm (prompt )) # if you have paid api_key from openai --> run this line
# Out:
# Certainly! Here are the steps to learn Machine Learning in Arabic:
#
# 1. Choose a machine learning course or book: There are many great books and courses available on the subject. Some popular ones include "Machine Learning: Concepts and Techniques" by Andrew Ng, "Hands-On Machine Learning with Scikit-Learn and TensorFlow" by David Gorecki, and "Deep Learning with Python" by David Gorecki.
